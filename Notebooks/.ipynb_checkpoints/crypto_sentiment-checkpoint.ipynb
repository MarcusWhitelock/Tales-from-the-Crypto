# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports and Installs
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
nltk.download('vader_lexicon')
from newsapi import NewsApiClient

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

from collections import Counter
from nltk import ngrams

from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

import spacy
from spacy import displacy

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\xElio\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\xElio\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Reading api key environment variable
load_dotenv()
api_key = os.getenv("NEWS_API_KEY")

# %%
# Creating a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetching the Bitcoin news articles
btc_articles = newsapi.get_everything(
    q="Bitcoin AND bitcoin AND BTC",
    language="en",
    page_size=20,
    sort_by="relevancy"
)

# Checking the amount articles containing Bitcoin
print(f"Amount of articles featuring Bitcoin: {btc_articles['totalResults']}")
# Out:
# Amount of articles featuring Bitcoin: 1712

# %%
# Fetching the Ethereum news articles
eth_articles = newsapi.get_everything(
    q="Ethereum AND ethereum AND ETH",
    language='en',
    page_size=20,
    sort_by="relevancy"
)

# Checking the amount of news articles containing Ethereum
print(f"Amount of articles featuringg Ethereum: {eth_articles['totalResults']}")
# Checking a sample to see what it contains 
print(f"First sample: {eth_articles['articles'][0]}")
# Out:
# Amount of articles featuringg Ethereum: 846
# First sample: {'source': {'id': 'the-verge', 'name': 'The Verge'}, 'author': 'Corin Faife', 'title': 'Crypto.com admits over $30 million stolen by hackers', 'description': 'Cryptocurrency exchange Crypto.com has said that $15 million in ethereum and $18 million in bitcoin were stolen by hackers in a security breach', 'url': 'https://www.theverge.com/2022/1/20/22892958/crypto-com-exchange-hack-bitcoin-ethereum-security', 'urlToImage': 'https://cdn.vox-cdn.com/thumbor/mde_l3lUC4muDPEFG7LYrUz0O3g=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/8921023/acastro_bitcoin_2.jpg', 'publishedAt': '2022-01-20T13:23:31Z', 'content': 'In a new blog post the company said that 4,836 ETH and 443 bitcoin were taken\r\nIllustration by Alex Castro / The Verge\r\nIn a blog post published in the early hours of Thursday morning, cryptocurrency… [+2004 chars]'}

# %%
# Create the Bitcoin sentiment scores DataFrame
btc_sents = []
for article in btc_articles["articles"]:
    try:
        title = article['title']
        text = article['content'].lower()
        date = article['publishedAt']
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
            
        btc_sents.append({
        "Title": title,
        "Text": text,
        "Date": date,
        "Compound": compound,
        "Positive": pos,
        "Negative": neg,
        "Neutral": neu})
    except AttributeError:
        pass
        
# Making it into a datarame
btc_df = pd.DataFrame(btc_sents)
# Viewing dataframe
btc_df.head()
# Out:
#                                                Title  \
# 0  Crypto.com admits over $30 million stolen by h...
# 1  Crypto.com loses $34 million in hack that affe...
# 2  Kazakhstan's bitcoin 'paradise' may be losing ...
# 3  Bitcoin billionaire Mike Novogratz says the $3...
# 4  A brief history of El Salvador’s crypto feud w...
#
#                                                 Text                  Date  \
# 0  in a new blog post the company said that 4,836...  2022-01-20T13:23:31Z
# 1  in an interview with bloomberg tv, crypto.com'...  2022-01-20T11:05:19Z
# 2  london, jan 14 (reuters) - kazakhstan may no l...  2022-01-14T13:45:00Z
# 3  bitcoin billionaire mike novogratz has said th...  2022-02-09T12:34:33Z
# 4  investing in crypto is a risky business partic...  2022-01-26T22:46:32Z
#
#    Compound  Positive  Negative  Neutral
# 0    0.0000     0.000     0.000    1.000
# 1    0.1027     0.046     0.000    0.954
# 2   -0.3400     0.000     0.093    0.907
# 3    0.4767     0.148     0.075    0.776
# 4    0.1779     0.075     0.054    0.871

# %%
# Create the Ethereum sentiment scores DataFrame
eth_sents = []
for article in eth_articles["articles"]:
    try:
        title = article['title']
        text = article['content'].lower()
        date = article['publishedAt'][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
            
        eth_sents.append({
        "Title": title,
        "Text": text,
        "Date": date,
        "Compound": compound,
        "Positive": pos,
        "Negative": neg,
        "Neutral": neu})
    except AttributeError:
        pass
        
# Making it into a datarame
eth_df = pd.DataFrame(eth_sents)
# Viewing dataframe
eth_df.head()
# Out:
#                                                Title  \
# 0  Crypto.com admits over $30 million stolen by h...
# 1  Crypto.com loses $34 million in hack that affe...
# 2  Blockchain platform Wormhole says it's retriev...
# 3  Hacker steals over $320M from blockchain platf...
# 4  Crypto Exchange Shuts Down Withdrawals After H...
#
#                                                 Text        Date  Compound  \
# 0  in a new blog post the company said that 4,836...  2022-01-20    0.0000
# 1  in an interview with bloomberg tv, crypto.com'...  2022-01-20    0.1027
# 2  online thieves made off with "wrapped ethereum...  2022-02-03    0.1027
# 3  online thieves made off with 120,000 weth, or ...  2022-02-03   -0.6808
# 4  the crypto market's whiplash volatility can ma...  2022-01-19    0.5574
#
#    Positive  Negative  Neutral
# 0     0.000     0.000    1.000
# 1     0.046     0.000    0.954
# 2     0.131     0.092    0.778
# 3     0.051     0.174    0.775
# 4     0.129     0.000    0.871

# %%
# Describe the Bitcoin Sentiment
btc_df.describe()
# Out:
#         Compound   Positive   Negative    Neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.060595   0.065500   0.050300   0.884200
# std     0.413394   0.065565   0.062712   0.090754
# min    -0.709600   0.000000   0.000000   0.712000
# 25%    -0.190050   0.000000   0.000000   0.830250
# 50%     0.051350   0.064500   0.026000   0.874500
# 75%     0.232225   0.091750   0.079500   0.951750
# max     0.902200   0.246000   0.185000   1.000000

# %%
# Describe the Ethereum Sentiment
eth_df.describe()
# Out:
#         Compound   Positive   Negative    Neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.048235   0.071850   0.058750   0.869400
# std     0.460089   0.070549   0.070281   0.098905
# min    -0.709600   0.000000   0.000000   0.596000
# 25%    -0.196200   0.000000   0.000000   0.828500
# 50%     0.102700   0.057500   0.023000   0.873000
# 75%     0.398550   0.129250   0.098750   0.931500
# max     0.670500   0.215000   0.196000   1.000000

# %% [markdown]
# ### Questions:
#
# **Q: Which coin had the highest mean positive score?**
#
# A: The Sentiment analysis shows us that Ethereum had the higher mean positive score with 0.069350 to BTC 0.058750
#
# **Q: Which coin had the highest compound score?**
#
# A: The Sentiment analysis shows us that Bitcoin has the highest compound score with 0.680800 to ETH 0.670500
#
# **Q. Which coin had the highest positive score?**
#
# A: The Sentiment analysis shows us that Ethereum had the highest positive score with 0.215000 to BTC 0.148000

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw = set(stopwords.words('english'))

# Expand the default stopwords list if necessary
sw_addon = {'url', 'urlToImage', 'ha', 'wa', 'char', 'said'}

# %%
# Complete the tokenizer function
def tokenizer(article):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', article)
    # Create a tokenized list of the words
    words = word_tokenize(re_clean)
    
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
   
    # Convert the words to lowercase
    # Remove the stop words
    tokens = [word.lower() for word in lem if word.lower() not in sw.union(sw_addon)]
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
# Create empty tokenized list
tokenized = []

# Tokenizing the Text column for each row of the DataFrame
for article in btc_df['Text']:
    # Tokenizer function to tokenize the article
    tokenized_articles = tokenizer(article)
    # Appending all tokens to list
    tokenized.append({'tokens':tokenized_articles})

# Making it a dataframe
tokens_df= pd.DataFrame(tokenized)

# Adding tokens to the new tokens column in original df
btc_df['Tokens'] = tokens_df

# Viewing
btc_df.head()
# Out:
#                                                Title  \
# 0  Crypto.com admits over $30 million stolen by h...
# 1  Crypto.com loses $34 million in hack that affe...
# 2  Kazakhstan's bitcoin 'paradise' may be losing ...
# 3  Bitcoin billionaire Mike Novogratz says the $3...
# 4  A brief history of El Salvador’s crypto feud w...
#
#                                                 Text                  Date  \
# 0  in a new blog post the company said that 4,836...  2022-01-20T13:23:31Z
# 1  in an interview with bloomberg tv, crypto.com'...  2022-01-20T11:05:19Z
# 2  london, jan 14 (reuters) - kazakhstan may no l...  2022-01-14T13:45:00Z
# 3  bitcoin billionaire mike novogratz has said th...  2022-02-09T12:34:33Z
# 4  investing in crypto is a risky business partic...  2022-01-26T22:46:32Z
#
#    Compound  Positive  Negative  Neutral  \
# 0    0.0000     0.000     0.000    1.000
# 1    0.1027     0.046     0.000    0.954
# 2   -0.3400     0.000     0.093    0.907
# 3    0.4767     0.148     0.075    0.776
# 4    0.1779     0.075     0.054    0.871
#
#                                               Tokens
# 0  [new, blog, post, company, eth, bitcoin, taken...
# 1  [interview, bloomberg, tv, cryptocoms, chief, ...
# 2  [london, jan, reuters, kazakhstan, may, longer...
# 3  [bitcoin, billionaire, mike, novogratz, recove...
# 4  [investing, crypto, risky, business, particula...

# %%
# Create a new tokens column for Ethereum
# Create empty tokenized list
tokenized = []

# Tokenizing the Text column for each row of the DataFrame
for article in eth_df['Text']:
    # Tokenizer function to tokenize the article
    tokenized_articles = tokenizer(article)
    # Appending all tokens to list
    tokenized.append({'tokens':tokenized_articles})

# Making it a dataframe
tokens_df= pd.DataFrame(tokenized)

# Adding tokens to the new tokens column in original df
eth_df['Tokens'] = tokens_df

# Viewing
eth_df.head()
# Out:
#                                                Title  \
# 0  Crypto.com admits over $30 million stolen by h...
# 1  Crypto.com loses $34 million in hack that affe...
# 2  Blockchain platform Wormhole says it's retriev...
# 3  Hacker steals over $320M from blockchain platf...
# 4  Crypto Exchange Shuts Down Withdrawals After H...
#
#                                                 Text        Date  Compound  \
# 0  in a new blog post the company said that 4,836...  2022-01-20    0.0000
# 1  in an interview with bloomberg tv, crypto.com'...  2022-01-20    0.1027
# 2  online thieves made off with "wrapped ethereum...  2022-02-03    0.1027
# 3  online thieves made off with 120,000 weth, or ...  2022-02-03   -0.6808
# 4  the crypto market's whiplash volatility can ma...  2022-01-19    0.5574
#
#    Positive  Negative  Neutral  \
# 0     0.000     0.000    1.000
# 1     0.046     0.000    0.954
# 2     0.131     0.092    0.778
# 3     0.051     0.174    0.775
# 4     0.129     0.000    0.871
#
#                                               Tokens
# 0  [new, blog, post, company, eth, bitcoin, taken...
# 1  [interview, bloomberg, tv, cryptocoms, chief, ...
# 2  [online, thief, made, wrapped, ethereum, worth...
# 3  [online, thief, made, weth, wrapped, ethereum,...
# 4  [crypto, market, whiplash, volatilitycan, make...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
# Generate the Bitcoin N-grams where N=2
btc_grams = ngrams(tokenizer(btc_df.Text.str.cat()), 2)
Counter(btc_grams).most_common(20)
# Out:
# [(('blog', 'post'), 2),
#  (('global', 'crypto'), 2),
#  (('crypto', 'mining'), 2),
#  (('market', 'cap'), 2),
#  (('exchange', 'platform'), 2),
#  (('super', 'bowl'), 2),
#  (('canceling', 'transaction'), 2),
#  (('new', 'blog'), 1),
#  (('post', 'company'), 1),
#  (('company', 'eth'), 1),
#  (('eth', 'bitcoin'), 1),
#  (('bitcoin', 'takenillustration'), 1),
#  (('takenillustration', 'alex'), 1),
#  (('alex', 'castro'), 1),
#  (('castro', 'vergein'), 1),
#  (('vergein', 'blog'), 1),
#  (('post', 'published'), 1),
#  (('published', 'early'), 1),
#  (('early', 'hour'), 1),
#  (('hour', 'thursday'), 1)]

# %%
# Generate the Ethereum N-grams where N=2
eth_grams = ngrams(tokenizer(eth_df.Text.str.cat()), 2)
Counter(eth_grams).most_common(20)
# Out:
# [(('blog', 'post'), 2),
#  (('charsonline', 'thief'), 2),
#  (('thief', 'made'), 2),
#  (('wrapped', 'ethereum'), 2),
#  (('ethereum', 'worth'), 2),
#  (('worth', 'nearly'), 2),
#  (('nearly', 'milliongetty'), 2),
#  (('milliongetty', 'imageshackers'), 2),
#  (('stole', 'million'), 2),
#  (('million', 'cryptocurrency'), 2),
#  (('cryptocurrency', 'wormhole'), 2),
#  (('wormhole', 'developer'), 2),
#  (('hacker', 'stole'), 2),
#  (('erc', 'token'), 2),
#  (('medical', 'debt'), 2),
#  (('new', 'blog'), 1),
#  (('post', 'company'), 1),
#  (('company', 'eth'), 1),
#  (('eth', 'bitcoin'), 1),
#  (('bitcoin', 'takenillustration'), 1)]

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
# Will create new list variable to separate from main df
toks_btc = []

# Have to use a loop in order to pull each token into the new list variable 
for tokens in btc_df["Tokens"]:
    toks_btc += tokens

# Getting top 10 words with a count feature within tokens library  
btc_top10 = token_count(toks_btc)
btc_top10
# Out:
# [('bitcoin', 11),
#  ('crypto', 8),
#  ('cryptocurrency', 6),
#  ('transaction', 5),
#  ('market', 4),
#  ('mining', 4),
#  ('new', 3),
#  ('global', 3),
#  ('hack', 3),
#  ('exchange', 3)]

# %%
# Use token_count to get the top 10 words for Bitcoin
# Will create new list variable to separate from main df
toks_eth = []

# Have to use a loop in order to pull each token into the new list variable 
for tokens in eth_df["Tokens"]:
    toks_eth += tokens

# Getting top 10 words with a count feature within tokens library  
eth_top10 = token_count(toks_eth)
eth_top10
# Out:
# [('ethereum', 8),
#  ('cryptocurrency', 6),
#  ('hacker', 4),
#  ('million', 4),
#  ('newsletter', 4),
#  ('protocol', 4),
#  ('eth', 3),
#  ('bitcoin', 3),
#  ('online', 3),
#  ('nearly', 3)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
# Generate the Bitcoin word cloud
wordcloud_plot_btc_df = ' '.join(toks_btc)
wc = WordCloud(width=1500, height=1000).generate(wordcloud_plot_btc_df)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show();

# %%
# Generate the Ethereum word cloud
wordcloud_plot_btc_df = ' '.join(toks_eth)
wc = WordCloud(width=1500, height=1000).generate(wordcloud_plot_btc_df)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show();

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
# Need just the text so will need to loop through articles and pull their texts into a new list variable 
listed_text = []

for text in btc_df['Text']:
    list_btc = text
    listed_text.append(list_btc)

# Join the items in the bitcoin_text list into one big string    
btc_text = ' '.join(listed_text)

# Inspect bitcoin_all_text_big_string
btc_text
# Out:
# 'in a new blog post the company said that 4,836 eth and 443 bitcoin were taken\r\nillustration by alex castro / the verge\r\nin a blog post published in the early hours of thursday morning, cryptocurrency… [+2004 chars] in an interview with bloomberg tv, crypto.com\'s chief executive kris marszalek has admitted that 400 customer accounts were compromised by hackers. he said his team detected unauthorized transactions… [+2811 chars] london, jan 14 (reuters) - kazakhstan may no longer be the bitcoin sanctuary it once was, according to some big miners who are looking to leave the global crypto hub following internet shutdowns last… [+4521 chars] bitcoin billionaire mike novogratz has said the recovery of $3.6 billion stolen in a 2016 hack on the bitfinex exchange is a positive sign for the crypto world, because it shows some of the merits of… [+2906 chars] investing in crypto is a risky business particularly when youre betting with a countrys future. its nonetheless a gamble that el salvadors president has been eager to make.\r\nnayib bukeles splurging o… [+6581 chars] i show how price manipulation to liquidate traders is done in cryptocurrency markets. i point fingers at people. thanks to coinstrats for allowing me to use their order book data for the analysis. al… [+21971 chars] every bitcoin transaction is stored in the distributed database known as the bitcoin blockchain.\r\nhowever, people have found ways to hack the bitcoin protocol to store more than just transactions. i\'… [+25681 chars] today i counted no fewer than 14 individuals doing this (based on unique ethereum and bitcoin addresses, address reuse, unique videos, registrar info, and unique domains), stealing roughly $200k in t… [+3258 chars] bitcoin rose above $44,000 briefly on monday, continuing the momentum from the end of last week and the weekend. the crypto was trading above its 50-day moving average monday, for the first time sinc… [+1830 chars] when can something bad also be used for good? the answer is crypto mining! \xa0\r\ntraditional crypto mining is notoriously resource-intensive with the annual carbon footprint of mining bitcoin equivalent… [+4569 chars] note: this is not investment advice and my investment disclosures are below.\r\nspecial thanks to my ali khan for running the scripts to grab and analyze pricing data. hes looking for an internship so … [+23280 chars] just two months ago, bitcoin and global crypto markets seemed hotter than ever: 1 btc was worth nearly $68,000, bringing its total market cap to $1.27 trillion; crypto’s global market cap was a mind-… [+4821 chars] the european union urgently needs to ban a form of cryptocurrency mining that is relying heavily on renewable energy, and poses a threat to climate-change goals, a top regional regulator said wednesd… [+3564 chars] coinbase launched the first in a series of payroll offerings:\r\nproud of the team for continuing to roll out new product innovations at a rapid pace. our us customers can now deposit a portion of thei… [+949 chars] two new york-based "tech entrepreneurs" were arrested on tuesday for allegedly conspiring to launder $4.5bn in stolen cryptocurrency, the us department of justice said, adding it\'s so far recovered $… [+4554 chars] francis ngannou has just announced on twitter that he will be taking half his purse for ufc 270 in the form of bitcoin.\r\n“the predator” is set to face off against his former teammate ciryl gane where… [+795 chars] big technology— by alex kantrowitz\r\nrevealing the systems in the tech world that drive what we see in the headlines, focusing primarily on the tech giants: amazon, apple, facebook, google, and micros… [+3 chars] cryptocurrency exchange platform ftx is slated to give away free bitcoins as a part of its ad campaign during super bowl lvi.\r\nthe crypto giveaway takes up a prime spot in super bowl ads and aims to … [+1533 chars] in 2016, a hong kong-based bitcoin exchange platform bitfinex was the subject of a hack that saw 119,756  ...

# %%
# Run the NER processor on all of the text
btc_ner = nlp(btc_text)

# Add a title to the document
btc_ner.user_data["title"] = "BTC Ner Processor"

# %%
# Render the visualization
displacy.render(btc_ner, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">BTC Ner Processor</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">in a new blog post the company said that
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4,836
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  eth and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     443
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     alex castro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>in a blog post published in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the early hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , cryptocurrency… [+2004 chars] in an interview with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bloomberg tv
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , crypto.com's chief executive
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kris marszalek
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has admitted that
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     400
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  customer accounts were compromised by hackers. he said his team detected unauthorized transactions… [+2811 chars]
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     london
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jan 14
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) -
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kazakhstan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  may no longer be the bitcoin sanctuary it once was, according to some big miners who are looking to leave the global crypto hub following internet shutdowns last… [+4521 chars] bitcoin billionaire
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mike novogratz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has said the recovery of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $3.6 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  stolen in a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2016
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  hack on the bitfinex exchange is a positive sign for the crypto world, because it shows some of the merits of… [+2906 chars] investing in crypto is a risky business particularly when youre betting with a countrys future. its nonetheless a gamble that
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     el salvadors
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nayib
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>however, people have found ways to hack the bitcoin protocol to store more than just transactions. i'… [+25681 chars]
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  i counted no fewer than 14 individuals doing this (based on unique ethereum and bitcoin addresses, address reuse, unique videos,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     registrar info
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and unique domains), stealing
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     roughly $200k
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in t… [+3258 chars] bitcoin rose
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     above $44,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  briefly

# %%
# List all Entities
btc_ents = set([print(ent.text, ent.label_) for ent in btc_ner.ents ])
btc_ents
# Out:
# 4,836 CARDINAL
# 443 CARDINAL
# alex castro PERSON
# the early hours TIME
# thursday DATE
# morning TIME
# bloomberg tv ORG
# kris marszalek PERSON
# 400 CARDINAL
# london GPE
# jan 14 DATE
# reuters ORG
# kazakhstan GPE
# mike novogratz PERSON
# $3.6 billion MONEY
# 2016 DATE
# el salvadors GPE
# nayib PERSON
# today DATE
# registrar info ORG
# roughly $200k MONEY
# above $44,000 MONEY
# monday DATE
# the end of last week DATE
# the weekend DATE
# 50-day DATE
# monday DATE
# first ORDINAL
# ali khan PERSON
# just two months ago DATE
# 1 CARDINAL
# nearly $68,000 MONEY
# $1.27 trillion MONEY
# the european union ORG
# first ORDINAL
# two CARDINAL
# new york GPE
# tuesday DATE
# 4.5bn MONEY
# the us department of justice ORG
# half CARDINAL
# 270 CARDINAL
# alex kantrowitz PERSON
# amazon ORG
# 2016 DATE
# hong kong GPE
# 119,756 CARDINAL
# approximately $63.7 million MONEY
# one CARDINAL
# {None}

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
# Need just the text so will need to loop through articles and pull their texts into a new list variable 
listed_text_eth = []

for text in eth_df['Text']:
    list_btc = text
    listed_text_eth.append(list_btc)

# Join the items in the bitcoin_text list into one big string    
eth_text = ' '.join(listed_text_eth)

# Inspect bitcoin_all_text_big_string
eth_text
# Out:
# 'in a new blog post the company said that 4,836 eth and 443 bitcoin were taken\r\nillustration by alex castro / the verge\r\nin a blog post published in the early hours of thursday morning, cryptocurrency… [+2004 chars] in an interview with bloomberg tv, crypto.com\'s chief executive kris marszalek has admitted that 400 customer accounts were compromised by hackers. he said his team detected unauthorized transactions… [+2811 chars] online thieves made off with "wrapped ethereum" worth nearly $324 million.\r\ngetty images\r\nhackers stole more than $324 million in cryptocurrency from wormhole, the developers behind the popular block… [+1664 chars] online thieves made off with 120,000 weth, or wrapped ethereum, worth nearly $324 million.\r\ngetty images\r\nhackers have stolen more than $324 million in cryptocurrency from wormhole, the developers be… [+1553 chars] the crypto market\'s whiplash volatility\xa0can make investing in certain coins feel like a major gamble, especially to those less familiar\xa0with the ins and outs of digital wallets and blockchain technol… [+1986 chars] welcome to\xa0tnw basics, a collection of tips, guides, and advice on how to easily get the most out of your gadgets, apps, and other stuff.\r\nif youve been on twitter recently, youll have seen people do… [+3873 chars] the bug appears to have been present for weeks and seems to be referenced in at least one tweet from january 1st, 2022. but exploitation of the bug has picked up significantly in the past day: blockc… [+1179 chars] a version of this article was published in time’s newsletter into the metaverse. subscribe for a weekly guide to the future of the internet.you can find past issues of the newsletter here.\r\nwhen vita… [+9697 chars] ethereum is a protocol undergoing significant changes. client teams are upgrading the protocol to scale to meet global demand while improving security and decentralization. beyond protocol developmen… [+5874 chars] after exploiting a wormhole vulnerability, hackers stole around $322 million from solana (sol), but the interoperability protocol has recently updated its users that the funds have been restored.\r\nac… [+1807 chars] crypto.com, a singapore-based cryptocurrency exchange, has denied reports that the firm lost nearly $15m in ethereum in a possible network intrusion over the weekend.\r\naccording to blockchain biz pec… [+2208 chars] the color museum wants to monetize the building blocks of nft avatars by licensing out the exclusive rights to specific hexadecimal colors on the blockchain, which you can select and name yourself. i… [+2019 chars] in 2022, ethereum stands as the second-most valuable cryptocurrency behind bitcoin. thousands of people buy and sell ethereum every day, but owning ethereum requires storing your private keys securel… [+8900 chars] today i counted no fewer than 14 individuals doing this (based on unique ethereum and bitcoin addresses, address reuse, unique videos, registrar info, and unique domains), stealing roughly $200k in t… [+3258 chars] weth is an erc20 token that is designed to have the same value as eth, essentially just erc20-ifying eth. all erc20 tokens are essentially just smart contracts (little computer programs that are host… [+1429 chars] crypto.com has just recognized that were was a cyber attack on its platform. \r\nusers were brought on to the news when their accounts suddenly required two-factor authentication sign-in, along with pa… [+489 chars] cb insights newsletter\r\n724,948 subscribers get our free newsletter to stay a step ahead on technology trends, venture capital, startups, and the industries of tomorrow. on thursday night, crypto twitter was overrun with people begging others to click their referral links for something called wtf. if you saw any of the many groveling tweets, you may have been wonderi… [+5180 chars] a hacker who stole more than $1 million from users of a cryptocurrency platform and then promised to return it keeping a tip for their servi ...

# %%
# Run the NER processor on all of the text
eth_ner = nlp(eth_text)

# Add a title to the document
eth_ner.user_data["title"] = "ETH Ner Processor"

# %%
# Render the visualization
displacy.render(eth_ner, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">ETH Ner Processor</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">in a new blog post the company said that
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4,836
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  eth and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     443
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     alex castro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>in a blog post published in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the early hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , cryptocurrency… [+2004 chars] in an interview with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bloomberg tv
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , crypto.com's chief executive
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kris marszalek
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has admitted that
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     400
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  customer accounts were compromised by hackers. he said his team detected unauthorized transactions… [+2811 chars] online thieves made off with &quot;wrapped ethereum&quot; worth
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly $324 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>hackers stole
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than $324 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in cryptocurrency from wormhole, the developers behind the popular block… [+1664 chars] online thieves made off with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     120,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  weth, or wrapped ethereum, worth
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly $324 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>hackers have stolen
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than $324 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>if youve been on twitter recently, youll have seen people do… [+3873 chars] the bug appears to have been present for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and seems to be referenced in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     at least one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  tweet from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     january 1st
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . but exploitation of the bug has picked up significantly in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# : blockc… [+1179 chars] a version of this article was published in time’s newsletter into the metaverse. subscribe for a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     weekly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>when vita… [+9697 chars] ethereum is a protocol undergoing significant changes. client teams are upgrading the protocol to scale to meet global demand while improving security and decentralization. beyond protocol developmen… [+5874 chars] after exploiting a wormhole vulnerability, hackers stole around
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $322 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>ac… [+1807 chars] crypto.com, a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em

# %%
# List all Entities
eth_ents = set([print(ent.text, ent.label_) for ent in eth_ner.ents])
eth_ents
# Out:
# 4,836 CARDINAL
# 443 CARDINAL
# alex castro PERSON
# the early hours TIME
# thursday DATE
# morning TIME
# bloomberg tv ORG
# kris marszalek PERSON
# 400 CARDINAL
# nearly $324 million MONEY
# more than $324 million MONEY
# 120,000 CARDINAL
# nearly $324 million MONEY
# more than $324 million MONEY
# weeks DATE
# at least one CARDINAL
# january 1st DATE
# 2022 DATE
# the past day DATE
# weekly DATE
# $322 million MONEY
# singapore GPE
# nearly $15m MONEY
# the weekend DATE
# 2022 DATE
# second ORDINAL
# thousands CARDINAL
# every day DATE
# today DATE
# registrar info ORG
# roughly $200k MONEY
# two CARDINAL
# 724,948 CARDINAL
# tomorrow DATE
# thursday DATE
# night TIME
# crypto PERSON
# more than $1 million MONEY
# wednesday DATE
# {None}

# %% [markdown]
# ---
